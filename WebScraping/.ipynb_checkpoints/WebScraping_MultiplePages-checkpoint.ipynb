# %% [markdown]
# # Scraping data from multiple web pages with the same structure (example)
# We will build the code that allow us to use wiki pages to retrieve information about a list of people.
# - first we will use the [code that retrieves data about a single person](WebScraping_SinglePage-NoInstructions.ipynb) to build a functions that allows to pass a person name and that returns a list of information about that person
# - second we will call the function for each one of Trump's friends
#
# See also:
# - [more information about python functions](http://www.tutorialspoint.com/python/python_functions.htm)
# - [more details about the code we use to define the function getPersonData](WebScraping_SinglePage.ipynb)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ## Define a functions that takes a person name and returns a list of information about that person

# %%
def getPersonData( name ):
    url = 'https://en.wikipedia.org/wiki/'+name
    r  = requests.get(url)
    data = r.text
    soup = BeautifulSoup(data)

    # create a list to store all the data
    personInfo = []

    
    # *** name ***
    # look for a div tag with a class named nickname
    # check that there is a name
    nameSection = soup.find("div", class_="nickname")
    if nameSection is not None :
        name = nameSection.get_text()

        # add the person name to the list
        personInfo.append(name)
        
    else : personInfo.append('none')

    # *** name ***
    # look for a span tag with a class named bday
    bdaySection=soup.find("span", class_="bday")
    if bdaySection is not None :
        bday=bdaySection.get_text()

        # add the person bday to the list
        personInfo.append(bday)
    
    else : personInfo.append('none')

    # *** education ***

    # find the th tag that has a text 'Education'
    edu_heading = soup.find("th", string="Education")
    if edu_heading is not None :

        # go one level up to the table row level
        edu_row = edu_heading.parent

        # get all links (this is how education info is stored)
        edu_list_with_tags = edu_row.find_all('a')

        # transform it into a list to be able to scroll through each element
        tagsList = list(edu_list_with_tags)

        # collect all [university, degree] pairs
        edu_list=[]
        for x in range(0,len(tagsList)-1, 2):
            edu_list.append([tagsList[x].string, tagsList[x+1].string])

        # add the person education to the list (converting it to a string)
        personInfo.append(str(edu_list))

    else : personInfo.append('none')


    # *** children ***

    # find the th tag that has a text 'Children'
    children_heading = soup.find("th", string="Children")
    if children_heading is not None :

        # retreive the number of children by getting the text of the next siblin
        numbChildren = children_heading.next_sibling.string

        # add the person children to the list
        personInfo.append(numbChildren)

    else : personInfo.append('none')

    return personInfo

# the line below tests the function
getPersonData('Reince_Priebus')
# Out:
# ['Reinhold Richard Priebus',
#  '1972-03-18',
#  "[['University of Wisconsin–Whitewater', 'BA'], ['University of Miami', 'JD']]",
#  '2']

# %%
# shows what the getPersonData returns for a non-person
getPersonData('DRUDGE REPORT')

# %% [markdown]
# ## Call the function for each one of Trump's friends

# %%
# read the file with the geocoded twitter data and build the dataFrame
df = pd.read_csv('geocodedTwitterData.csv', sep=',')
df.head()
# Out:
#    Unnamed: 0     screen_name              name  followers_count  \
# 0           0   TuckerCarlson    Tucker Carlson          1064787
# 1           3      WhiteHouse   The White House         15327283
# 2           5  KellyannePolls  Kellyanne Conway          1664393
# 3           6          Reince    Reince Priebus           941927
# 4          10  RealRomaDowney       Roma Downey           192126
#
#          location        lat         lon
# 0  Washington, DC  38.895009  -77.036563
# 1  Washington, DC  38.895009  -77.036563
# 2  Washington, DC  38.895009  -77.036563
# 3     Kenosha, WI  42.584677  -87.821226
# 4          Malibu  34.035591 -118.689423

# %%
# call the getPersonData function for all names in the column 'name' of the dataFrame
allInfo = []
for name in df['name']:
    #store the data returned by the fuction in the list allInfo
    allInfo.append(getPersonData(name))
allInfo
# Out:
# [['Tucker McNear Carlson[1]', '1969-05-16', '[]', '4'],
#  ['none', '1792-10-13', 'none', 'none'],
#  ['Kellyanne Elizabeth Fitzpatrick',
#   '1967-01-20',
#   "[['Trinity Washington University', 'BA'], ['George Washington University', 'JD']]",
#   '4'],
#  ['Reinhold Richard Priebus',
#   '1972-03-18',
#   "[['University of Wisconsin–Whitewater', 'BA'], ['University of Miami', 'JD']]",
#   '2'],
#  ['none', '1960-05-06', 'none', '1 daughter, 2 stepsons'],
#  ['none', '1923', 'none', 'none'],
#  ['Laura Anne Ingraham',
#   '1963-06-19',
#   "[['Dartmouth College', 'BA'], ['University of Virginia', 'JD']]",
#   '3'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['Lara Lea Yunaska', '1982-10-12', 'none', '1'],
#  ['Sean Patrick Hannity[1]', '1961-12-30', '[]', '2'],
#  ['none', '1973-09-18', "[[None, 'BA'], ['American University', 'MA']]", '4'],
#  ['Ann Hart Coulter',
#   '1961-12-08',
#   "[['Cornell University', 'BA'], ['University of Michigan', 'JD']]",
#   'none'],
#  ['none', 'none', 'none', 'none'],
#  ['Katrina Lanette Shaddix', '1976-07-20', 'none', '1'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['Gerald Michael Riviera',
#   '1943-07-04',
#   "[['State University of New York Maritime College', 'University of Arizona'], ['BS', 'Brooklyn Law School']]",
#   '5'],
#  ['Eric Thomas Bolling', 'none', "[['Rollins College', 'BA']]", '1'],
#  ['James Mark Burnett[1]',
#   '1960-07-17',
#   'none',
#   '3, including a step-daughter'],
#  ['none',
#   '1935-11-01',
#   'none',
#   'Jennifer, Marc, Wayne, Michele, Theresa, Amanda'],
#  ['Vincent Kennedy McMahon', '1945-08-24', '[]', None],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['Greta Conway Van Susteren[1]',
#   '1954-06-11',
#   "[['University of Wisconsin', 'B.A.'], ['Georgetown University', 'J.D.']]",
#   'none'],
#  ["Piers Stefan O'Meara",
#   '1965-03-30',
#   "[['Chailey School', 'Priory School, Lewes']]",
#   '4'],
#  ['Ivana Marie Trump',
#   '1981-10-30',
#   "[['Georgetown University', 'University of Pennsylvania']]",
#   '3'],
#  ['Michael Richard Pence',
#   '1959-06-07',
#   "[['Hanover College', 'BA'], ['Indiana University, Indianapolis', 'JD']]",
#   None],
#  ['Bradley James Parscale',
#   '1976-01-03',
#   "[['University of Texas, San Antonio', 'Trinity University']]",
#   '1'],
#  ['Sarah Elizabeth Huckabee',
#   '1982-08-13',
#   "[['Ouachita Baptist University', 'BA']]",
#   '3'],
#  ['Tucker McNear Carlson[1]', '1969-05-16', '[]', '4'],
#  ['none', '1792-10-13', 'none', 'none'],
#  ['Daniel Scavino Jr.',
#   'none',
#   "[['State University of New York, Plattsburgh', 'BA']]",
#   'none'],
#  ['Kellyanne Elizabeth Fitzpatrick',
#   '1967-01-20',
#   "[['Trinity Washington University', 'BA'], ['George Washington University', 'JD']]",
#   '4'],
#  ['Reinhold Richard Priebus',
#   '1972-03-18',
#   "[['University of Wisconsin–Whitewater', 'BA'], ['University of Miami', 'JD']]",
#   '2'],
#  ['none', '1960-05-06', 'none', '1 daughter, 2 stepsons'],
#  ['none', '1923', 'none', 'none'],
#  ['Laura Anne Ingraham',
#   '1963-06-19',
#   "[['Dartmouth College', 'BA'], ['University of Virginia', 'JD']]",
#   '3'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['Lara Lea Yunaska', '1982-10-12', 'none', '1'],
#  ['Sean Patrick Hannity[1]', '1961-12-30', '[]', '2'],
#  ['none', '1973-09-18', "[[None, 'BA'], ['American University', 'MA']]", '4'],
#  ['none', 'none', 'none', 'none'],
#  ['Katrina Lanette Shaddix', '1976-07-20', 'none', '1'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['Gerald Michael Riviera',
#   '1943-07-04',
#   "[['State University of New York Maritime College', 'University of Arizona'], ['BS', 'Brooklyn Law School']]",
#   '5'],
#  ['none', 'none', 'none', 'none'],
#  ['James Mark Burnett[1]',
#   '1960-07-17',
#   'none',
#   '3, including a step-daughter'],
#  ['none',
#   '1935-11-01',
#   'none',
#   'Jennifer, Marc, Wayne, Michele, Theresa, Amanda'],
#  ['Vincent Kennedy McMahon', '1945-08-24', '[]', None],
#  ['Daniel Scavino Jr.',
#   'none',
#   "[['State University of New York, Plattsburgh', 'BA']]",
#   'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['none', 'none', 'none', 'none'],
#  ['Greta Conway Van Susteren[1]',
#   '1954-06-11',
#   "[['University of Wisconsin', 'B.A.'], ['Georgetown University', 'J.D.']]",
#   'none'],
#  ["Piers Stefan O'Meara",
#   '1965-03-30',
#   "[['Chailey School', 'Priory School, Lewes']]",
#   '4'],
#  ['Ivana Marie Trump',
#   '1981-10-30',
#   "[['Georgetown University', 'University of Pennsylvania']]",
#   '3']]

# %% [markdown]
# ## Add the information found to the original DataFrame

# %%
# create a new dataFrame from the allInfo list
df_new = pd.DataFrame(allInfo)

# assign column names
df_new=df_new.rename(columns = {0:'nickName', 1:'bday', 2:'education', 3:'children'})

# add the columns to the original dataFrame
df['nickName']=df_new['nickName']
df['bday']=df_new['bday']
df['education']=df_new['education']
df['children']=df_new['children']

# %%
df
# Out:
#     Unnamed: 0      screen_name                    name  followers_count  \
# 0            0    TuckerCarlson          Tucker Carlson          1064787
# 1            3       WhiteHouse         The White House         15327283
# 2            5   KellyannePolls        Kellyanne Conway          1664393
# 3            6           Reince          Reince Priebus           941927
# 4           10   RealRomaDowney             Roma Downey           192126
# 5           11            Trump      Trump Organization           254702
# 6           14    IngrahamAngle          Laura Ingraham          1664852
# 7           16        TeamTrump     Official Team Trump           742514
# 8           17    DRUDGE_REPORT           DRUDGE REPORT          1319753
# 9           19     LaraLeaTrump              Lara Trump           301998
# 10          20      seanhannity            Sean Hannity          2754923
# 11          22    CLewandowski_    Corey R. Lewandowski           285315
# 12          23       AnnCoulter             Ann Coulter          1662294
# 13          24   DiamondandSilk       Diamond and Silk®           382889
# 16                             none        none
# 17                             none        none
# 18           Gerald Michael Riviera  1943-07-04
# 19              Eric Thomas Bolling        none
# 20            James Mark Burnett[1]  1960-07-17
# 21                             none  1935-11-01
# 22          Vincent Kennedy McMahon  1945-08-24
# 23                             none        none
# 24                             none        none
# 25                             none        none
# 26                             none        none
# 27                             none        none
# 28                             none        none
# 29                             none        none
# ..                              ...         ...
# 39               Daniel Scavino Jr.        none
# 40  Kellyanne Elizabeth Fitzpatrick  1967-01-20
# 41         Reinhold Richard Priebus  1972-03-18
# 42                             none  1960-05-06
# 43                             none        1923
# 44              Laura Anne Ingraham  1963-06-19
# 45                             none        none
# 46                             none        none
# 47                 Lara Lea Yunaska  1982-10-12
# 48          Sean Patrick Hannity[1]  1961-12-30
# 49                             none  1973-09-18
# 50                             none        none
# 51          Katrina Lanette Shaddix  1976-07-20
# 52                             none        none
# 53                             none        none
# 54           Gerald Michael Riviera  1943-07-04
# 55                             none        none
# 56            James Mark Burnett[1]  1960-07-17
# 57                             none  1935-11-01
# 58          Vincent Kennedy McMahon  1945-08-24
# 59               Daniel Scavino Jr.        none
# 60                             none        none
# 61                             none        none
# 62                             none        none
# 63                             none        none
# 64                             none        none
# 65                             none        none
# 66     Greta Conway Van Susteren[1]  1954-06-11
# 67             Piers Stefan O'Meara  1965-03-30
# 68                Ivana Marie Trump  1981-10-30
#
#                                             education  \
# 0                                                  []
# 1                                                none
# 2   [['Trinity Washington University', 'BA'], ['Ge...
# 3   [['University of Wisconsin–Whitewater', 'BA'],...
# 4                                                none
# 5                                                none
# 6   [['Dartmouth College', 'BA'], ['University of ...
# 7                                                none
# 8                                                none
# 9                                                none
# 10                                                 []
# 11      [[None, 'BA'], ['American University', 'MA']]
# 12  [['Cornell University', 'BA'], ['University of...
# 13                                               none
# 14                                               none
# 15                                               none
# 16                                               none
# 17                                               none
# 18  [['State University of New York Maritime Colle...
# 19                        [['Rollins College', 'BA']]
# 20                                               none
# 21                                               none
# 22                                                 []
# 23                                               none
# 24                                               none
# 25                                               none
# 26                                               none
# 27                                               none
# 28                                               none
# 29                                               none
# ..                                                ...
# 39  [['State University of New York, Plattsburgh',...
# 40  [['Trinity Washington University', 'BA'], ['Ge...
# 41  [['University of Wisconsin–Whitewater', 'BA'],...
# 42                                               none
# 43                                               none
# 44  [['Dartmouth College', 'BA'], ['University of ...
# 45                                               none
# 46                                               none
# 47                                               none
# 48                                                 []
# 49      [[None, 'BA'], ['American University', 'MA']]
# 50                                               none
# 51                                               none
# 52                                               none
# 53                                               none
# 54  [['State University of New York Maritime Colle...
# 55                                               none
# 56                                               none
# 57                                               none
# 58                                                 []
# 59  [['State University of New York, Plattsburgh',...
# 60                                               none
# 61                                               none
# 62                                               none
# 63                                               none
# 64                                               none
# 65                                               none
# 66  [['University of Wisconsin', 'B.A.'], ['George...
# 67       [['Chailey School', 'Priory School, Lewes']]
# 68  [['Georgetown University', 'University of Penn...
#
#                                            children
# 0                                                 4
# 1                                              none
# 2                                                 4
# 3                                                 2
# 4                            1 daughter, 2 stepsons
# 5                                              none
# 6                                                 3
# 7                                              none
# 8                                              none
# 9                                                 1
# 10                                                2
# 11                                                4
# 12                                             none
# 13                                             none
# 14                                                1
# 15                                             none
# 16                                             none
# 17                                             none
# 18                                                5
# 19                                                1
# 20                     3, including a step-daughter
# 21  Jennifer, Marc, Wayne, Michele, Theresa, Amanda
# 22                                             None
# 23                                             none
# 24                                             none
# 25                                             none
# 26                                             none
# 27                                             none
# 28                                             none
# 29                                             none
# ..                                              ...
# 39                                             none
# 40                                                4
# 41                                                2
# 42                           1 daughter, 2 stepsons
# 43                                             none
# 44                                                3
# 45                                             none
# 46                                             none
# 47                                                1
# 48                                                2
# 49                                                4
# 50                                             none
# 51                                                1
# 52                                             none
# 53                                             none
# 54                                                5
# 55                                             none
# 56                     3, including a step-daughter
# 57  Jennifer, Marc, Wayne, Michele, Theresa, Amanda
# 58                                             None
# 59                                             none
# 60                                             none
# 61                                             none
# 62                                             none
# 63                                             none
# 64                                             none
# 65                                             none
# 66                                             none
# 67                                                4
# 68                                                3
#
# [69 rows x 11 columns]

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#         screen_name                    name  followers_count  \
# 0     TuckerCarlson          Tucker Carlson          1064787
# 1        WhiteHouse         The White House         15327283
# 2    KellyannePolls        Kellyanne Conway          1664393
# 3            Reince          Reince Priebus           941927
# 4    RealRomaDowney             Roma Downey           192126
# 5             Trump      Trump Organization           254702
# 6     IngrahamAngle          Laura Ingraham          1664852
# 7         TeamTrump     Official Team Trump           742514
# 8     DRUDGE_REPORT           DRUDGE REPORT          1319753
# 9      LaraLeaTrump              Lara Trump           301998
# 10      seanhannity            Sean Hannity          2754923
# 11    CLewandowski_    Corey R. Lewandowski           285315
# 12       AnnCoulter             Ann Coulter          1662294
# 13   DiamondandSilk       Diamond and Silk®           382889
# 14   KatrinaPierson         Katrina Pierson           339906
# 15  MichaelCohen212           Michael Cohen           257489
# 16    foxandfriends           FOX & friends          1012750
# 17     MELANIATRUMP           MELANIA TRUMP           892678
# 18    GeraldoRivera          Geraldo Rivera           157925
# 19      ericbolling            Eric Bolling           729649
# 20    MarkBurnettTV            Mark Burnett           193488
# 21       garyplayer             Gary Player           359255
# 22     VinceMcMahon           Vince McMahon          1789522
# 23     TrumpWaikiki           Trump Waikiki            48325
# 24       TrumpDoral    Trump National Doral            56443
# 25   TrumpCharlotte         Trump Charlotte            38486
# 26    TrumpLasVegas       Trump Vegas Hotel            99719
# 27     TrumpChicago     Trump Hotel Chicago            67529
# 28      TrumpGolfDC    Trump Washington, DC            56428
# 29      TrumpGolfLA       Trump Los Angeles            47512
# ..              ...                     ...              ...
# 39        Scavino45         Dan Scavino Jr.           340876
# 40   KellyannePolls        Kellyanne Conway          2584390
# 41           Reince          Reince Priebus           934750
# 42   RealRomaDowney             Roma Downey           238918
# 43            Trump  The Trump Organization           350208
# 45                                       USA  39.783730 -100.445882
# 46                                       USA  39.783730 -100.445882
# 47                              New York, NY  40.730862  -73.987156
# 48                              New York, NY  40.730862  -73.987156
# 49                            Washington, DC  38.895009  -77.036563
# 50                                       USA  39.783730 -100.445882
# 51                            Washington, DC  38.895009  -77.036563
# 52                              New York, NY  40.730862  -73.987156
# 53                              New York, NY  40.730862  -73.987156
# 54                              New York, NY  40.730862  -73.987156
# 55                              New York, NY  40.730862  -73.987156
# 56                           Los Angeles, CA  34.053683 -118.242767
# 57                              South Africa -28.816624   24.991639
# 58                          Greenwich, Conn.  41.026486  -73.628460
# 59                            Washington, DC  38.895009  -77.036563
# 60                            Miami, Florida  25.774266  -80.193659
# 61                             Charlotte, NC  35.227087  -80.843127
# 62                                Las Vegas   36.166286 -115.149225
# 63                               Chicago, IL  41.875562  -87.624421
# 64                              Sterling, VA  39.001619  -77.403201
# 65                           Los Angeles, CA  34.053683 -118.242767
# 66                            Washington, DC  38.895009  -77.036563
# 67                           Los Angeles, CA  34.053683 -118.242767
# 68                            Washington, DC  38.895009  -77.036563
#
#                            nickName        bday  \
# 0          Tucker McNear Carlson[1]  1969-05-16
# 1                              none  1792-10-13
# 2   Kellyanne Elizabeth Fitzpatrick  1967-01-20
# 3          Reinhold Richard Priebus  1972-03-18
# 4                              none  1960-05-06
# 5                              none        1923
# 6               Laura Anne Ingraham  1963-06-19
# 7                              none        none
# 8                              none        none
# 9                  Lara Lea Yunaska  1982-10-12
# 10          Sean Patrick Hannity[1]  1961-12-30
# 11                             none  1973-09-18
# 12                 Ann Hart Coulter  1961-12-08
# 13                             none        none
# 14          Katrina Lanette Shaddix  1976-07-20
# 15                             none        none
# 16                             none        none
# 17                             none        none
# 18           Gerald Michael Riviera  1943-07-04
# 19              Eric Thomas Bolling        none
# 20            James Mark Burnett[1]  1960-07-17
# 21                             none  1935-11-01
# 22          Vincent Kennedy McMahon  1945-08-24
# 23                             none        none
# 24                             none        none
# 25                             none        none
# 26                             none        none
# 27                             none        none
# 28                             none        none
# 29                             none        none
# ..                              ...         ...
# 39               Daniel Scavino Jr.        none
# 40  Kellyanne Elizabeth Fitzpatrick  1967-01-20
# 41         Reinhold Richard Priebus  1972-03-18
# 42                             none  1960-05-06
# 43                             none        1923
# 44              Laura Anne Ingraham  1963-06-19
# 45                             none        none
# 46                             none        none
# 47                 Lara Lea Yunaska  1982-10-12
# 48          Sean Patrick Hannity[1]  1961-12-30
# 49                             none  1973-09-18
# 50                             none        none
# 51          Katrina Lanette Shaddix  1976-07-20
# 52                             none        none
# 53                             none        none
# 54           Gerald Michael Riviera  1943-07-04
# 55                             none        none
# 56            James Mark Burnett[1]  1960-07-17
# 57                             none  1935-11-01
# 58          Vincent Kennedy McMahon  1945-08-24
# 59               Daniel Scavino Jr.        none
# 60                             none        none
# 61                             none        none
# 62                             none        none
# 63                             none        none
# 64                             none        none
# 65                             none        none
# 66     Greta Conway Van Susteren[1]  1954-06-11
# 67             Piers Stefan O'Meara  1965-03-30
# 68                Ivana Marie Trump  1981-10-30
#
#                                             education  \
# 0                                                  []
# 1                                                none
# 2   [['Trinity Washington University', 'BA'], ['Ge...
# 3   [['University of Wisconsin–Whitewater', 'BA'],...
# 4                                                none
# 5                                                none
# 6   [['Dartmouth College', 'BA'], ['University of ...
# 7                                                none
# 8                                                none
# 9                                                none
# 10                                                 []
# 11      [[None, 'BA'], ['American University', 'MA']]
# 12  [['Cornell University', 'BA'], ['University of...
# 13                                               none
# 14                                               none
# 15                                               none
# 16                                               none
# 17                                               none
# 18  [['State University of New York Maritime Colle...
# 19                        [['Rollins College', 'BA']]
# 20                                               none
# 21                                               none
# 22                                                 []
# 23                                               none
# 24                                               none
# 25                                               none
# 26                                               none
# 27                                               none
# 28                                               none
# 29                                               none
# ..                                                ...
# 39  [['State University of New York, Plattsburgh',...
# 40  [['Trinity Washington University', 'BA'], ['Ge...
# 41  [['University of Wisconsin–Whitewater', 'BA'],...
# 42                                               none
# 43                                               none
# 44  [['Dartmouth College', 'BA'], ['University of ...
# 45                                               none
# 46                                               none
# 47                                               none
# 48                                                 []
# 49      [[None, 'BA'], ['American University', 'MA']]
# 50                                               none
# 51                                               none
# 52                                               none
# 53                                               none
# 54  [['State University of New York Maritime Colle...
# 55                                               none
# 56                                               none
# 57                                               none
# 58                                                 []
# 59  [['State University of New York, Plattsburgh',...
# 60                                               none
# 61                                               none
# 62                                               none
# 63                                               none
# 64                                               none
# 65                                               none
# 66  [['University of Wisconsin', 'B.A.'], ['George...
# 67       [['Chailey School', 'Priory School, Lewes']]
# 68  [['Georgetown University', 'University of Penn...
#
#                                            children
# 0                                                 4
# 1                                              none
# 2                                                 4
# 3                                                 2
# 4                            1 daughter, 2 stepsons
# 5                                              none
# 6                                                 3
# 7                                              none
# 8                                              none
# 9                                                 1
# 10                                                2
# 11                                                4
# 12                                             none
# 13                                             none
# 14                                                1
# 15                                             none
# 16                                             none
# 17                                             none
# 18                                                5
# 19                                                1
# 20                     3, including a step-daughter
# 21  Jennifer, Marc, Wayne, Michele, Theresa, Amanda
# 22                                             None
# 23                                             none
# 24                                             none
# 25                                             none
# 26                                             none
# 27                                             none
# 28                                             none
# 29                                             none
# ..                                              ...
# 39                                             none
# 40                                                4
# 41                                                2
# 42                           1 daughter, 2 stepsons
# 43                                             none
# 44                                                3
# 45                                             none
# 46                                             none
# 47                                                1
# 48                                                2
# 49                                                4
# 50                                             none
# 51                                                1
# 52                                             none
# 53                                             none
# 54                                                5
# 55                                             none
# 56                     3, including a step-daughter
# 57  Jennifer, Marc, Wayne, Michele, Theresa, Amanda
# 58                                             None
# 59                                             none
# 60                                             none
# 61                                             none
# 62                                             none
# 63                                             none
# 64                                             none
# 65                                             none
# 66                                             none
# 67                                                4
# 68                                                3
#
# [69 rows x 10 columns]

# %%
df.to_csv('geocodedAndCompletedTwittedData.csv')
