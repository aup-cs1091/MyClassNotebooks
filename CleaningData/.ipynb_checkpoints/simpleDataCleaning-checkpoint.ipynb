# %% [markdown]
# # This code shows some simple data cleaning procedures
#
# Note that, in order to make the code simple, many details (sometimes quite important) are not considered.
#
# The input file used as example is the one generated in the TwitterFriends example
#
#
# ## Main items introduced
# 1. Simple data cleaning strategies
# 2. Reading and writing dataframes from CSV files
#   * pd.read_csv
#   * df.to_csv
# 3. Exploring dataframes
#   * df - shows beginning and end of table
#   * df.head() - shows the first five rows
#   * df\[&lt;column_name&gt;\] - shows the column &lt;column_name&gt;
#   * df\[&lt;column_name&gt;\]\[&lt;row number&gt;\] - shows the content of the cell
#   * df.dtypes - shows the type of each column
#   * df\[&lt;column_name&gt;\].unique() - shows unique values of the items in the column &lt;column_name&gt;
#   * df\[df.&lt;column_name&gt; == '&lt;value&gt;'\] - returns all rows that have the value &lt;value&gt; in the column &lt;column_name&gt;. Note that the condition in the square bracket may be complex, see for example code line 21
# 4. Manipulating dataframes
#   * df.copy() - creates a copy of the datframe
#   * df.dropna(PARAM) - rows or columns based on NaN (no value assigned)
#   * df.drop(PARAM) - drop rows or columns
#   * df.replace(PARAM) - replaces the content of cells
#   * df\['&lt;column_name&gt;'\]\[&lt;row number&gt;\] = '&lt;value&gt;' - assignes the value &lt;value&gt; to the cell
# 5. Simple regular expressions

# %%
import pandas as pd
import numpy as np

# %%
# read the file generated with the twitter API in a data frame and show first five records
df = pd.read_csv('dataFromTwitter.txt', sep='\t')
df.head()
# Out:
#                                    screen_name             name  \
# 0                                TuckerCarlson   Tucker Carlson
# 1                                jessebwatters    Jesse Watters
# 2  https://t.co/cbHoqt3QTG https://t.co/ODX77…              NaN
# 3                                   WhiteHouse  The White House
# 4                                    Scavino45  Dan Scavino Jr.
#
#   followers_count              location  \
# 0         1064787        Washington, DC
# 1          410410                   NaN
# 2             NaN                   NaN
# 3        15327283      Washington, D.C.
# 4          148667  @Twitter @DanScavino
#
#                                               status
# 0        Thanks for joining! https://t.co/YNNjGghUxR
# 1  RT @FNC_Ladies_Rule: 🍾🎉Fox News is No. 1 Basic...
# 2                                                NaN
# 3  Lt. Gen. (Ret) Keith Kellogg: "Trump as Comman...
# 4  'It is time to heal the wounds that have divid...

# %%
# show the entire data frame - note the summary (number of row and columns) at the end
df
# Out:
#                                            screen_name                  name  \
# 0                                        TuckerCarlson        Tucker Carlson
# 1                                        jessebwatters         Jesse Watters
# 2          https://t.co/cbHoqt3QTG https://t.co/ODX77…                   NaN
# 3                                           WhiteHouse       The White House
# 4                                            Scavino45       Dan Scavino Jr.
# 5                                       KellyannePolls      Kellyanne Conway
# 6                                               Reince        Reince Priebus
# 7                                    ✔️$10B investment                   NaN
# 8                                           ✔️13K jobs                   NaN
# 9                                    ✔️ #MadeInAmerica                   NaN
# 10                                      RealRomaDowney           Roma Downey
# 11                                               Trump    Trump Organization
# 12                                           TrumpGolf            Trump Golf
# 13                                       TiffanyATrump  Tiffany Ariana Trump
# 14                                       IngrahamAngle        Laura Ingraham
# 15                                          mike_pence            Mike Pence
# 16                                           TeamTrump   Official Team Trump
# 17                                       DRUDGE_REPORT         DRUDGE REPORT
# 18                                     MrsVanessaTrump         Vanessa Trump
# 19                                        LaraLeaTrump            Lara Trump
# 20                                         seanhannity          Sean Hannity
# 21                                           foxnation            Fox Nation
# 22                                       CLewandowski_  Corey R. Lewandowski
# 23                                          AnnCoulter           Ann Coulter
# 24                                      DiamondandSilk     Diamond and Silk®
# 25                                      KatrinaCampins       KATRINA CAMPINS
# 26                                      KatrinaPierson       Katrina Pierson
# 27                                     MichaelCohen212         Michael Cohen
# 28                                       foxandfriends         FOX & friends
# 29                                        MELANIATRUMP         MELANIA TRUMP
# ..                                                 ...                   ...
# 74                                        LaraLeaTrump            Lara Trump
# 75                                         seanhannity          Sean Hannity
# 76                                       CLewandowski_  Corey R. Lewandowski
# 77                                      DiamondandSilk     Diamond and Silk®
# 78                                      KatrinaCampins       KATRINA CAMPINS
# 79                                      KatrinaPierson       Katrina Pierson
# 80                             https://t.co/kL6SoClx4K                   NaN
# 81                                       foxandfriends         FOX & friends
# 82                                        MELANIATRUMP         MELANIA TRUMP
# 83                                       GeraldoRivera        Geraldo Rivera
# 84                                         ericbolling        Eric Bolling🇺🇸
# 85                                     @CBSEveningNews                   NaN
# 86   CBS NEWS POLL: 76% of viewers approved of what...                   NaN
# 87                                       MarkBurnettTV          Mark Burnett
# 88                                          garyplayer           Gary Player
# 89                                        VinceMcMahon         Vince McMahon
# 90                                          DanScavino           Dan Scavino
# 91                                          TrumpDoral  Trump National Doral
# 92                                      TrumpCharlotte       Trump Charlotte
# 93                                       TrumpLasVegas     Trump Vegas Hotel
# 94                                        TrumpChicago   Trump Hotel Chicago
# 95                                         TrumpGolfDC   Trump Washington DC
# 96                                         TrumpGolfLA     Trump Los Angeles
# 97                                           EricTrump            Eric Trump
# 98                                         BillOReilly         Bill O'Reilly
# 99                                               greta    Greta Van Susteren
# 100       📽️ig: hedgehog_azuki https://t.co/96alP2JT13                   NaN
# 101                                        piersmorgan          Piers Morgan
# 102                                     DonaldJTrumpJr      Donald Trump Jr.
# 103                                        IvankaTrump          Ivanka Trump
#
#     followers_count                        location  \
# 0           1064787                  Washington, DC
# 1            410410                             NaN
# 2               NaN                             NaN
# 3          15327283                Washington, D.C.
# 4            148667            @Twitter @DanScavino
# 5           1664393                  Washington, DC
# 6            941927  Kenosha, WI and Washington, DC
# 7               NaN                             NaN
# 8               NaN                             NaN
# 9               NaN                             NaN
# 10           192126                          Malibu
# 11           254702                    New York, NY
# 12            66333                             NaN
# 13           429759                             NaN
# 14          1664852                              DC
# 15          2257112                             NaN
# 16           742514                             USA
# 17          1319753                              US
# 18           215576                             NaN
# 19           301998                   New York City
# 20          2754923                             NYC
# 21           393715                             NaN
# 22           285315                  Washington, DC
# 23          1662294                 Los Angeles/NYC
# 24           382889                   United States
# 25           307559                    Peace Within
# 26           339906                  Washington, DC
# 27           257489                        New York
# 28          1012750                   New York City
# 29           892678                   New York City
# ..              ...                             ...
# 74           492595                   New York City
# 75          3928199                             NYC
# 76           388884                  Washington, DC
# 77          1010717                   United States
# 78           273821                    Peace Within
# 79           443386                  Washington, DC
# 80              NaN                             NaN
# 81          1335507                   New York City
# 82          1064983                   New York City
# 83           265232                   New York City
# 84          1080806                             NYC
# 85              NaN                             NaN
# 86              NaN                             NaN
# 87           219525                     Los Angeles
# 88           393259                    South Africa
# 89          2197623                Greenwich, Conn.
# 90           507539                  Washington, DC
# 91            87502                  Miami, Florida
# 92            69155                   Charlotte, NC
# 93           126917                      Las Vegas
# 94            94208                     Chicago, IL
# 95            98794                    Sterling, VA
# 96            81502                 Los Angeles, CA
# 97          2329040                             NaN
# 98          2967067                             NaN
# 99          1201546                      Washington
# 100             NaN                             NaN
# 101         6535363             London, Newick, LA.
# 102         3300797                             NaN
# 103         6159430                  Washington, DC
#
#                                                 status
# 0          Thanks for joining! https://t.co/YNNjGghUxR
# 1    RT @FNC_Ladies_Rule: 🍾🎉Fox News is No. 1 Basic...
# 2                                                  NaN
# 3    Lt. Gen. (Ret) Keith Kellogg: "Trump as Comman...
# 4    'It is time to heal the wounds that have divid...
# 5    Important read: Gen. Kellogg combines personal...
# 6    Thanks to @POTUS, Foxconn, @ScottWalker, @PRya...
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10   Kindness matters 🦋 #bekind https://t.co/telXo6...
# 11   Brighten up your mornings in the Windy City wi...
# 12   Rejoice in the ride and leave the rest to us! ...
# 13   🌖🌗🌘🌑🌒🌓#SolarEclipse2017 @ Lijst van bekende me...
# 14   Is it "normalcy" to govern by by "continuing r...
# 15   Since day 1, @realDonaldTrump has been fightin...
# 16   RT @WhiteHouse: Watch LIVE as President Trump ...
# 17   Now ISIS threatens Rome... https://t.co/ZOjKSk...
# 18   RT @DonaldJTrumpJr: The most interesting measu...
# 19   RT @JennaBrowder: "He truly is a man of God" -...
# 20   Health warning to protestors!  Do not fight wi...
# 21   #Obama's Bureaucrats Are Still Running the Tit...
# 22   CFPB chief Cordray thinks he’s above the law –...
# 23   RT @immigrant4trump: Camping World tells Trump...
# 24   When will the Fake News start to realize that ...
# 25   Babymoon Vacation! Very fitting given the Scol...
# 26   RT @realDonaldTrump: If Republican Senate does...
# 27   RT @PressSec: .@POTUS: “It is time to heal the...
# 28   Join us tomorrow on the plaza! Country star @J...
# 29                          🇺🇸 https://t.co/CcV2HZ1roV
# ..                                                 ...
# 74   RT @EricTrump: I’ll be on ⁦@SeanHannity⁩ with ...
# 75   WATCH BELOW: Entire Congress ERUPTS in Biparti...
# 76   President’s State of the Union promises an Ame...
# 77   RT @SteveKingIA: Some shots from the #StateOfT...
# 78   South Florida Mansion Sales Surge as Tax Exile...
# 79                          RT @realDonaldTrump: #SOTU
# 80                                                 NaN
# 81   After the Show Show: @jrodfromoz explains what...
# 82   RT @FLOTUS: This has been a year filled with m...
# 83   For all her admirable qualities: compassionate...
# 84                                    CBS Evening News
# 85                                                 NaN
# 86                                                 NaN
# 87   RT @EcoChallengeMGM: Team Registration is now ...
# 88   RT @jacknicklaus: Feats of strength by my “old...
# 89   Unflinching, uncompromising and unmistakably T...
# 90   25 years of being on the links with @realDonal...
# 91   @JoeyBaboots @RiggsBarstool @DonaldJTrumpJr @E...
# 92   We are right there with you, Eric and will con...
# 93   Life is cool by the pool... but it's even cool...
# 94   RT @EricTrump: Record-breaking cold temperatur...
# 95   Trump National DC offers a beautiful ballroom ...
# 96   Make sure this Sunday will be truly Super! Vis...
# 97   I’ll be on ⁦@SeanHannity⁩ with ⁦@LaraLeaTrump⁩...
# 98   Americans watching last night's #SOTU saw a fa...
# 99             RT @AMAZlNGNATURE: He likes an apple 🍎🦔
# 100                                                NaN
# 101     They can't afford me.. https://t.co/Ud3cjo2Ck3
# 102  I guess she doesn’t want to put an end to sex ...
# 103  RT @USAIDMBekkering: Thanks to @IvankaTrump &a...
#
# [104 rows x 5 columns]

# %%
# each column can be accessed by providing its name
df['name']
# Out:
# 0            Tucker Carlson
# 1             Jesse Watters
# 2                       NaN
# 3           The White House
# 4           Dan Scavino Jr.
# 5          Kellyanne Conway
# 6            Reince Priebus
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10              Roma Downey
# 11       Trump Organization
# 12               Trump Golf
# 13     Tiffany Ariana Trump
# 14           Laura Ingraham
# 15               Mike Pence
# 16      Official Team Trump
# 17            DRUDGE REPORT
# 18            Vanessa Trump
# 19               Lara Trump
# 20             Sean Hannity
# 21               Fox Nation
# 22     Corey R. Lewandowski
# 23              Ann Coulter
# 24        Diamond and Silk®
# 25          KATRINA CAMPINS
# 26          Katrina Pierson
# 27            Michael Cohen
# 28            FOX & friends
# 29            MELANIA TRUMP
#                ...
# 74               Lara Trump
# 75             Sean Hannity
# 76     Corey R. Lewandowski
# 77        Diamond and Silk®
# 78          KATRINA CAMPINS
# 79          Katrina Pierson
# 80                      NaN
# 81            FOX & friends
# 82            MELANIA TRUMP
# 83           Geraldo Rivera
# 84           Eric Bolling🇺🇸
# 85                      NaN
# 86                      NaN
# 87             Mark Burnett
# 88              Gary Player
# 89            Vince McMahon
# 90              Dan Scavino
# 91     Trump National Doral
# 92          Trump Charlotte
# 93        Trump Vegas Hotel
# 94      Trump Hotel Chicago
# 95      Trump Washington DC
# 96        Trump Los Angeles
# 97               Eric Trump
# 98            Bill O'Reilly
# 99       Greta Van Susteren
# 100                     NaN
# 101            Piers Morgan
# 102        Donald Trump Jr.
# 103            Ivanka Trump
# Name: name, Length: 104, dtype: object

# %%
# each element can be accessed by providing the name of the column and the row number
df['name'][96]
# Out:
# 'Trump Los Angeles'

# %%
# Every column has a type (in this case all columns contain objects)
df.dtypes
# Out:
# screen_name        object
# name               object
# followers_count    object
# location           object
# status             object
# dtype: object

# %% [markdown]
# #### Do exercises 1,2 and 3 in the CleaningDataExercises notebook

# %%
# make a copy of the data frame
df1 = df.copy()
# dropna allows to drop lines (or columns if axis=1) that contain non assigned values (NaN)
# in this case I have indicated to drop the lines that have NaN in the location column (subset=['location'])
df2 = df1.dropna(subset=['location'], axis=0, how='any')

# %%
df2
# Out:
#          screen_name                    name followers_count  \
# 0      TuckerCarlson          Tucker Carlson         1064787
# 3         WhiteHouse         The White House        15327283
# 4          Scavino45         Dan Scavino Jr.          148667
# 5     KellyannePolls        Kellyanne Conway         1664393
# 6             Reince          Reince Priebus          941927
# 10    RealRomaDowney             Roma Downey          192126
# 11             Trump      Trump Organization          254702
# 14     IngrahamAngle          Laura Ingraham         1664852
# 16         TeamTrump     Official Team Trump          742514
# 17     DRUDGE_REPORT           DRUDGE REPORT         1319753
# 19      LaraLeaTrump              Lara Trump          301998
# 20       seanhannity            Sean Hannity         2754923
# 22     CLewandowski_    Corey R. Lewandowski          285315
# 23        AnnCoulter             Ann Coulter         1662294
# 24    DiamondandSilk       Diamond and Silk®          382889
# 25    KatrinaCampins         KATRINA CAMPINS          307559
# 26    KatrinaPierson         Katrina Pierson          339906
# 27   MichaelCohen212           Michael Cohen          257489
# 28     foxandfriends           FOX & friends         1012750
# 29      MELANIATRUMP           MELANIA TRUMP          892678
# 30     GeraldoRivera          Geraldo Rivera          157925
# 31       ericbolling            Eric Bolling          729649
# 32     MarkBurnettTV            Mark Burnett          193488
# 33        garyplayer             Gary Player          359255
# 34      VinceMcMahon           Vince McMahon         1789522
# 36      TrumpWaikiki           Trump Waikiki           48325
# 37        TrumpDoral    Trump National Doral           56443
# 38    TrumpCharlotte         Trump Charlotte           38486
# 39     TrumpLasVegas       Trump Vegas Hotel           99719
# 40      TrumpChicago     Trump Hotel Chicago           67529
# ..               ...                     ...             ...
# 61    KellyannePolls        Kellyanne Conway         2584390
# 62            Reince          Reince Priebus          934750
# 63    RealRomaDowney             Roma Downey          238918
# 64             Trump  The Trump Organization          350208
# 67     IngrahamAngle          Laura Ingraham         2581320
# 69         TeamTrump     Official Team Trump          956501
# 72     DRUDGE_REPORT           DRUDGE REPORT         1403331
# 74      LaraLeaTrump              Lara Trump          492595
# 75       seanhannity            Sean Hannity         3928199
# 76     CLewandowski_    Corey R. Lewandowski          388884
# 77    DiamondandSilk       Diamond and Silk®         1010717
# 78    KatrinaCampins         KATRINA CAMPINS          273821
# 79    KatrinaPierson         Katrina Pierson          443386
# 81     foxandfriends           FOX & friends         1335507
# 82      MELANIATRUMP           MELANIA TRUMP         1064983
# 83     GeraldoRivera          Geraldo Rivera          265232
# 84       ericbolling          Eric Bolling🇺🇸         1080806
# 87     MarkBurnettTV            Mark Burnett          219525
# 88        garyplayer             Gary Player          393259
# 89      VinceMcMahon           Vince McMahon         2197623
# 90        DanScavino             Dan Scavino          507539
# 91        TrumpDoral    Trump National Doral           87502
# 92    TrumpCharlotte         Trump Charlotte           69155
# 93     TrumpLasVegas       Trump Vegas Hotel          126917
# 94      TrumpChicago     Trump Hotel Chicago           94208
# 95       TrumpGolfDC     Trump Washington DC           98794
# 96       TrumpGolfLA       Trump Los Angeles           81502
# 99             greta      Greta Van Susteren         1201546
# 101      piersmorgan            Piers Morgan         6535363
# 103      IvankaTrump            Ivanka Trump         6159430
#
#                            location  \
# 0                    Washington, DC
# 3                  Washington, D.C.
# 4              @Twitter @DanScavino
# 5                    Washington, DC
# 6    Kenosha, WI and Washington, DC
# 10                           Malibu
# 11                     New York, NY
# 14                               DC
# 16                              USA
# 17                               US
# 19                    New York City
# 20                              NYC
# 22                   Washington, DC
# 23                  Los Angeles/NYC
# 24                    United States
# 25                     Peace Within
# 26                   Washington, DC
# 27                         New York
# 28                    New York City
# 29                    New York City
# 30                    New York City
# 31                              NYC
# 32                      Los Angeles
# 33                     South Africa
# 34                 Greenwich, Conn.
# 36                    Waikiki, Oahu
# 37                   Miami, Florida
# 38                    Charlotte, NC
# 39                       Las Vegas
# 40                      Chicago, IL
# ..                              ...
# 61                            USA🇺🇸
# 62   Kenosha, WI and Washington, DC
# 63                  California, USA
# 64                     New York, NY
# 67                               DC
# 69                              USA
# 72                               US
# 74                    New York City
# 75                              NYC
# 76                   Washington, DC
# 77                    United States
# 78                     Peace Within
# 79                   Washington, DC
# 81                    New York City
# 82                    New York City
# 83                    New York City
# 84                              NYC
# 87                      Los Angeles
# 88                     South Africa
# 89                 Greenwich, Conn.
# 90                   Washington, DC
# 91                   Miami, Florida
# 92                    Charlotte, NC
# 93                       Las Vegas
# 94                      Chicago, IL
# 95                     Sterling, VA
# 96                  Los Angeles, CA
# 99                       Washington
# 101             London, Newick, LA.
# 103                  Washington, DC
#
#                                                 status
# 0          Thanks for joining! https://t.co/YNNjGghUxR
# 3    Lt. Gen. (Ret) Keith Kellogg: "Trump as Comman...
# 4    'It is time to heal the wounds that have divid...
# 5    Important read: Gen. Kellogg combines personal...
# 6    Thanks to @POTUS, Foxconn, @ScottWalker, @PRya...
# 10   Kindness matters 🦋 #bekind https://t.co/telXo6...
# 11   Brighten up your mornings in the Windy City wi...
# 14   Is it "normalcy" to govern by by "continuing r...
# 16   RT @WhiteHouse: Watch LIVE as President Trump ...
# 17   Now ISIS threatens Rome... https://t.co/ZOjKSk...
# 19   RT @JennaBrowder: "He truly is a man of God" -...
# 20   Health warning to protestors!  Do not fight wi...
# 22   CFPB chief Cordray thinks he’s above the law –...
# 23   RT @immigrant4trump: Camping World tells Trump...
# 24   When will the Fake News start to realize that ...
# 25   Babymoon Vacation! Very fitting given the Scol...
# 26   RT @realDonaldTrump: If Republican Senate does...
# 27   RT @PressSec: .@POTUS: “It is time to heal the...
# 28   Join us tomorrow on the plaza! Country star @J...
# 29                          🇺🇸 https://t.co/CcV2HZ1roV
# 30   I'm with @GeorgeForeman &amp; #CharlesBarkley ...
# 31   I will continue to fight against these false s...
# 32   RT @FunderdomeABC: It's all about smart busine...
# 33                       #LOVE https://t.co/mN10m0SnK3
# 34   .@JohnCena continues to inspire countless peop...
# 36   Join us for #yoga @ 7:00am Mon, Weds &amp; Fri...
# 37   With fall around the corner, it's time to book...
# 38   RT @TrumpRealty: 138 Yacht Road; the ideal spa...
# 39   Roasted #salmon with chorizo &amp; navy bean f...
# 40   RT @amybizzarri: Indulge in Summery Spa Treatm...
# ..                                                 ...
# 61   RT @Liz_Cheney: Things my Democrat women colle...
# 62   RT @Reince: @realDonaldTrump Nails it again!  ...
# 63                                  @IrishCentral 💛☘️💛
# 64   The American football season might be over but...
# 67   Reading, writing and left-wing activism: “Durh...
# 69   Join President Trump in El Paso, Texas on MONDAY!
# 72          APPLE scrambles... https://t.co/jEUlOh8L38
# 74   RT @EricTrump: I’ll be on ⁦@SeanHannity⁩ with ...
# 75   WATCH BELOW: Entire Congress ERUPTS in Biparti...
# 76   President’s State of the Union promises an Ame...
# 77   RT @SteveKingIA: Some shots from the #StateOfT...
# 78   South Florida Mansion Sales Surge as Tax Exile...
# 79                          RT @realDonaldTrump: #SOTU
# 81   After the Show Show: @jrodfromoz explains what...
# 82   RT @FLOTUS: This has been a year filled with m...
# 83   For all her admirable qualities: compassionate...
# 84                                    CBS Evening News
# 87   RT @EcoChallengeMGM: Team Registration is now ...
# 88   RT @jacknicklaus: Feats of strength by my “old...
# 89   Unflinching, uncompromising and unmistakably T...
# 90   25 years of being on the links with @realDonal...
# 91   @JoeyBaboots @RiggsBarstool @DonaldJTrumpJr @E...
# 92   We are right there with you, Eric and will con...
# 93   Life is cool by the pool... but it's even cool...
# 94   RT @EricTrump: Record-breaking cold temperatur...
# 95   Trump National DC offers a beautiful ballroom ...
# 96   Make sure this Sunday will be truly Super! Vis...
# 99             RT @AMAZlNGNATURE: He likes an apple 🍎🦔
# 101     They can't afford me.. https://t.co/Ud3cjo2Ck3
# 103  RT @USAIDMBekkering: Thanks to @IvankaTrump &a...
#
# [73 rows x 5 columns]

# %%
# remove the status column
df2.drop(['status'], inplace=True, axis=1)
df2
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#          screen_name                    name followers_count  \
# 0      TuckerCarlson          Tucker Carlson         1064787
# 3         WhiteHouse         The White House        15327283
# 4          Scavino45         Dan Scavino Jr.          148667
# 5     KellyannePolls        Kellyanne Conway         1664393
# 6             Reince          Reince Priebus          941927
# 10    RealRomaDowney             Roma Downey          192126
# 11             Trump      Trump Organization          254702
# 14     IngrahamAngle          Laura Ingraham         1664852
# 16         TeamTrump     Official Team Trump          742514
# 17     DRUDGE_REPORT           DRUDGE REPORT         1319753
# 19      LaraLeaTrump              Lara Trump          301998
# 20       seanhannity            Sean Hannity         2754923
# 22     CLewandowski_    Corey R. Lewandowski          285315
# 23        AnnCoulter             Ann Coulter         1662294
# 24    DiamondandSilk       Diamond and Silk®          382889
# 25    KatrinaCampins         KATRINA CAMPINS          307559
# 26    KatrinaPierson         Katrina Pierson          339906
# 27   MichaelCohen212           Michael Cohen          257489
# 28     foxandfriends           FOX & friends         1012750
# 29      MELANIATRUMP           MELANIA TRUMP          892678
# 30     GeraldoRivera          Geraldo Rivera          157925
# 31       ericbolling            Eric Bolling          729649
# 32     MarkBurnettTV            Mark Burnett          193488
# 33        garyplayer             Gary Player          359255
# 34      VinceMcMahon           Vince McMahon         1789522
# 36      TrumpWaikiki           Trump Waikiki           48325
# 37        TrumpDoral    Trump National Doral           56443
# 38    TrumpCharlotte         Trump Charlotte           38486
# 39     TrumpLasVegas       Trump Vegas Hotel           99719
# 40      TrumpChicago     Trump Hotel Chicago           67529
# ..               ...                     ...             ...
# 61    KellyannePolls        Kellyanne Conway         2584390
# 62            Reince          Reince Priebus          934750
# 63    RealRomaDowney             Roma Downey          238918
# 64             Trump  The Trump Organization          350208
# 67     IngrahamAngle          Laura Ingraham         2581320
# 69         TeamTrump     Official Team Trump          956501
# 72     DRUDGE_REPORT           DRUDGE REPORT         1403331
# 74      LaraLeaTrump              Lara Trump          492595
# 75       seanhannity            Sean Hannity         3928199
# 76     CLewandowski_    Corey R. Lewandowski          388884
# 77    DiamondandSilk       Diamond and Silk®         1010717
# 78    KatrinaCampins         KATRINA CAMPINS          273821
# 79    KatrinaPierson         Katrina Pierson          443386
# 81     foxandfriends           FOX & friends         1335507
# 82      MELANIATRUMP           MELANIA TRUMP         1064983
# 83     GeraldoRivera          Geraldo Rivera          265232
# 84       ericbolling          Eric Bolling🇺🇸         1080806
# 87     MarkBurnettTV            Mark Burnett          219525
# 88        garyplayer             Gary Player          393259
# 89      VinceMcMahon           Vince McMahon         2197623
# 90        DanScavino             Dan Scavino          507539
# 91        TrumpDoral    Trump National Doral           87502
# 92    TrumpCharlotte         Trump Charlotte           69155
# 93     TrumpLasVegas       Trump Vegas Hotel          126917
# 94      TrumpChicago     Trump Hotel Chicago           94208
# 95       TrumpGolfDC     Trump Washington DC           98794
# 96       TrumpGolfLA       Trump Los Angeles           81502
# 99             greta      Greta Van Susteren         1201546
# 101      piersmorgan            Piers Morgan         6535363
# 103      IvankaTrump            Ivanka Trump         6159430
#
#                            location
# 0                    Washington, DC
# 3                  Washington, D.C.
# 4              @Twitter @DanScavino
# 5                    Washington, DC
# 6    Kenosha, WI and Washington, DC
# 10                           Malibu
# 11                     New York, NY
# 14                               DC
# 16                              USA
# 17                               US
# 19                    New York City
# 20                              NYC
# 22                   Washington, DC
# 23                  Los Angeles/NYC
# 24                    United States
# 25                     Peace Within
# 26                   Washington, DC
# 27                         New York
# 28                    New York City
# 29                    New York City
# 30                    New York City
# 31                              NYC
# 32                      Los Angeles
# 33                     South Africa
# 34                 Greenwich, Conn.
# 36                    Waikiki, Oahu
# 37                   Miami, Florida
# 38                    Charlotte, NC
# 39                       Las Vegas
# 40                      Chicago, IL
# ..                              ...
# 61                            USA🇺🇸
# 62   Kenosha, WI and Washington, DC
# 63                  California, USA
# 64                     New York, NY
# 67                               DC
# 69                              USA
# 72                               US
# 74                    New York City
# 75                              NYC
# 76                   Washington, DC
# 77                    United States
# 78                     Peace Within
# 79                   Washington, DC
# 81                    New York City
# 82                    New York City
# 83                    New York City
# 84                              NYC
# 87                      Los Angeles
# 88                     South Africa
# 89                 Greenwich, Conn.
# 90                   Washington, DC
# 91                   Miami, Florida
# 92                    Charlotte, NC
# 93                       Las Vegas
# 94                      Chicago, IL
# 95                     Sterling, VA
# 96                  Los Angeles, CA
# 99                       Washington
# 101             London, Newick, LA.
# 103                  Washington, DC
#
# [73 rows x 4 columns]

# %%
# remove 4rth row which has a strange location
df2.drop([4], inplace=True, axis=0)
df2
# Out:
#          screen_name                    name followers_count  \
# 0      TuckerCarlson          Tucker Carlson         1064787
# 3         WhiteHouse         The White House        15327283
# 5     KellyannePolls        Kellyanne Conway         1664393
# 6             Reince          Reince Priebus          941927
# 10    RealRomaDowney             Roma Downey          192126
# 11             Trump      Trump Organization          254702
# 14     IngrahamAngle          Laura Ingraham         1664852
# 16         TeamTrump     Official Team Trump          742514
# 17     DRUDGE_REPORT           DRUDGE REPORT         1319753
# 19      LaraLeaTrump              Lara Trump          301998
# 20       seanhannity            Sean Hannity         2754923
# 22     CLewandowski_    Corey R. Lewandowski          285315
# 23        AnnCoulter             Ann Coulter         1662294
# 24    DiamondandSilk       Diamond and Silk®          382889
# 25    KatrinaCampins         KATRINA CAMPINS          307559
# 26    KatrinaPierson         Katrina Pierson          339906
# 27   MichaelCohen212           Michael Cohen          257489
# 28     foxandfriends           FOX & friends         1012750
# 29      MELANIATRUMP           MELANIA TRUMP          892678
# 30     GeraldoRivera          Geraldo Rivera          157925
# 31       ericbolling            Eric Bolling          729649
# 32     MarkBurnettTV            Mark Burnett          193488
# 33        garyplayer             Gary Player          359255
# 34      VinceMcMahon           Vince McMahon         1789522
# 36      TrumpWaikiki           Trump Waikiki           48325
# 37        TrumpDoral    Trump National Doral           56443
# 38    TrumpCharlotte         Trump Charlotte           38486
# 39     TrumpLasVegas       Trump Vegas Hotel           99719
# 40      TrumpChicago     Trump Hotel Chicago           67529
# 41       TrumpGolfDC     Trump Washington DC           56428
# ..               ...                     ...             ...
# 61    KellyannePolls        Kellyanne Conway         2584390
# 62            Reince          Reince Priebus          934750
# 63    RealRomaDowney             Roma Downey          238918
# 64             Trump  The Trump Organization          350208
# 67     IngrahamAngle          Laura Ingraham         2581320
# 69         TeamTrump     Official Team Trump          956501
# 72     DRUDGE_REPORT           DRUDGE REPORT         1403331
# 74      LaraLeaTrump              Lara Trump          492595
# 75       seanhannity            Sean Hannity         3928199
# 76     CLewandowski_    Corey R. Lewandowski          388884
# 77    DiamondandSilk       Diamond and Silk®         1010717
# 78    KatrinaCampins         KATRINA CAMPINS          273821
# 79    KatrinaPierson         Katrina Pierson          443386
# 81     foxandfriends           FOX & friends         1335507
# 82      MELANIATRUMP           MELANIA TRUMP         1064983
# 83     GeraldoRivera          Geraldo Rivera          265232
# 84       ericbolling          Eric Bolling🇺🇸         1080806
# 87     MarkBurnettTV            Mark Burnett          219525
# 88        garyplayer             Gary Player          393259
# 89      VinceMcMahon           Vince McMahon         2197623
# 90        DanScavino             Dan Scavino          507539
# 91        TrumpDoral    Trump National Doral           87502
# 92    TrumpCharlotte         Trump Charlotte           69155
# 93     TrumpLasVegas       Trump Vegas Hotel          126917
# 94      TrumpChicago     Trump Hotel Chicago           94208
# 95       TrumpGolfDC     Trump Washington DC           98794
# 96       TrumpGolfLA       Trump Los Angeles           81502
# 99             greta      Greta Van Susteren         1201546
# 101      piersmorgan            Piers Morgan         6535363
# 103      IvankaTrump            Ivanka Trump         6159430
#
#                            location
# 0                    Washington, DC
# 3                  Washington, D.C.
# 5                    Washington, DC
# 6    Kenosha, WI and Washington, DC
# 10                           Malibu
# 11                     New York, NY
# 14                               DC
# 16                              USA
# 17                               US
# 19                    New York City
# 20                              NYC
# 22                   Washington, DC
# 23                  Los Angeles/NYC
# 24                    United States
# 25                     Peace Within
# 26                   Washington, DC
# 27                         New York
# 28                    New York City
# 29                    New York City
# 30                    New York City
# 31                              NYC
# 32                      Los Angeles
# 33                     South Africa
# 34                 Greenwich, Conn.
# 36                    Waikiki, Oahu
# 37                   Miami, Florida
# 38                    Charlotte, NC
# 39                       Las Vegas
# 40                      Chicago, IL
# 41                     Sterling, VA
# ..                              ...
# 61                            USA🇺🇸
# 62   Kenosha, WI and Washington, DC
# 63                  California, USA
# 64                     New York, NY
# 67                               DC
# 69                              USA
# 72                               US
# 74                    New York City
# 75                              NYC
# 76                   Washington, DC
# 77                    United States
# 78                     Peace Within
# 79                   Washington, DC
# 81                    New York City
# 82                    New York City
# 83                    New York City
# 84                              NYC
# 87                      Los Angeles
# 88                     South Africa
# 89                 Greenwich, Conn.
# 90                   Washington, DC
# 91                   Miami, Florida
# 92                    Charlotte, NC
# 93                       Las Vegas
# 94                      Chicago, IL
# 95                     Sterling, VA
# 96                  Los Angeles, CA
# 99                       Washington
# 101             London, Newick, LA.
# 103                  Washington, DC
#
# [72 rows x 4 columns]

# %%
# check the unique values in the column location
df2['location'].unique()
# Out:
# array(['Washington, DC', 'Washington, D.C.',
#        'Kenosha, WI and Washington, DC', 'Malibu', 'New York, NY', 'DC',
#        'USA', 'US', 'New York City', 'NYC', 'Los Angeles/NYC',
#        'United States', 'Peace Within', 'New York',
#        '                 NYC', 'Los Angeles', 'South Africa',
#        'Greenwich, Conn.', 'Waikiki, Oahu', 'Miami, Florida',
#        'Charlotte, NC', 'Las Vegas ', 'Chicago, IL', 'Sterling, VA',
#        'Los Angeles, CA', 'Manhasset, NY', 'Washington',
#        'London, Newick, LA. ', 'location', '1600 Pennsylvania Avenue ',
#        'USA🇺🇸', 'California, USA', 'London, Newick, LA.'], dtype=object)

# %% [markdown]
# Washington appears in many different formats
# the lines below replace all occurences of Washington to be the same
# I have used the function replace of the pandas library (see http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html ) and a regular expression to indicate that any sequence starting by Wash and followed by any sequence of characters should be replaced by 'Washington, DC'. A good tutprial on regular expressions is at https://regexone.com/

# %%
df3=df2.replace(to_replace=r'Wash.+',value='Washington, DC', regex=True)
df3['location'].unique()
# Out:
# array(['Washington, DC', 'Kenosha, WI and Washington, DC', 'Malibu',
#        'New York, NY', 'DC', 'USA', 'US', 'New York City', 'NYC',
#        'Los Angeles/NYC', 'United States', 'Peace Within', 'New York',
#        '                 NYC', 'Los Angeles', 'South Africa',
#        'Greenwich, Conn.', 'Waikiki, Oahu', 'Miami, Florida',
#        'Charlotte, NC', 'Las Vegas ', 'Chicago, IL', 'Sterling, VA',
#        'Los Angeles, CA', 'Manhasset, NY', 'London, Newick, LA. ',
#        'location', '1600 Pennsylvania Avenue ', 'USA🇺🇸',
#        'California, USA', 'London, Newick, LA.'], dtype=object)

# %%
# note that df2 has not changed
df2['location'].unique()
# Out:
# array(['Washington, DC', 'Washington, D.C.',
#        'Kenosha, WI and Washington, DC', 'Malibu', 'New York, NY', 'DC',
#        'USA', 'US', 'New York City', 'NYC', 'Los Angeles/NYC',
#        'United States', 'Peace Within', 'New York',
#        '                 NYC', 'Los Angeles', 'South Africa',
#        'Greenwich, Conn.', 'Waikiki, Oahu', 'Miami, Florida',
#        'Charlotte, NC', 'Las Vegas ', 'Chicago, IL', 'Sterling, VA',
#        'Los Angeles, CA', 'Manhasset, NY', 'Washington',
#        'London, Newick, LA. ', 'location', '1600 Pennsylvania Avenue ',
#        'USA🇺🇸', 'California, USA', 'London, Newick, LA.'], dtype=object)

# %%
# replace any DC at the beginning of the string with Washington, DC
# replace NYC preceded by any number of white spaces with New York, NY
# replace a string starting and finishing with US with USA
# replace USA🇺🇸 with USA
# replace New York City with New York, NY
# replace a string starting and finishing with New York with New York, NY
df4=df3.replace(regex={r'^DC': 'Washington, DC', '\s*NYC': 'New York, NY', '^US$':'USA', 'USA🇺🇸': 'USA', 'New York City': 'New York, NY', '^New York$':'New York, NY'})
df4['location'].unique()
# Out:
# array(['Washington, DC', 'Kenosha, WI and Washington, DC', 'Malibu',
#        'New York, NY', 'USA', 'Los Angeles/New York, NY', 'United States',
#        'Peace Within', 'Los Angeles', 'South Africa', 'Greenwich, Conn.',
#        'Waikiki, Oahu', 'Miami, Florida', 'Charlotte, NC', 'Las Vegas ',
#        'Chicago, IL', 'Sterling, VA', 'Los Angeles, CA', 'Manhasset, NY',
#        'London, Newick, LA. ', 'location', '1600 Pennsylvania Avenue ',
#        'California, USA', 'London, Newick, LA.'], dtype=object)

# %%
# Explore which are the entities with a certain location value (e.g. which ones have USA as location)
# (for each one of the rows in df4, [df4.location == 'USA'] returns true or false; only the rows corresponding to True are returned)
df4[df4.location == 'USA']
# Out:
#        screen_name                 name followers_count location
# 16       TeamTrump  Official Team Trump          742514      USA
# 17   DRUDGE_REPORT        DRUDGE REPORT         1319753      USA
# 61  KellyannePolls     Kellyanne Conway         2584390      USA
# 69       TeamTrump  Official Team Trump          956501      USA
# 72   DRUDGE_REPORT        DRUDGE REPORT         1403331      USA

# %%
# One location value is location, I want to see to what it corresponds
df4[df4.location == 'location']
# Out:
#     screen_name  name  followers_count  location
# 50  screen_name  name  followers_count  location

# %%
# I drop the line 50
df4.drop([50], inplace=True, axis=0)
df4
# Out:
#          screen_name                    name followers_count  \
# 0      TuckerCarlson          Tucker Carlson         1064787
# 3         WhiteHouse         The White House        15327283
# 5     KellyannePolls        Kellyanne Conway         1664393
# 6             Reince          Reince Priebus          941927
# 10    RealRomaDowney             Roma Downey          192126
# 11             Trump      Trump Organization          254702
# 14     IngrahamAngle          Laura Ingraham         1664852
# 16         TeamTrump     Official Team Trump          742514
# 17     DRUDGE_REPORT           DRUDGE REPORT         1319753
# 19      LaraLeaTrump              Lara Trump          301998
# 20       seanhannity            Sean Hannity         2754923
# 22     CLewandowski_    Corey R. Lewandowski          285315
# 23        AnnCoulter             Ann Coulter         1662294
# 24    DiamondandSilk       Diamond and Silk®          382889
# 25    KatrinaCampins         KATRINA CAMPINS          307559
# 26    KatrinaPierson         Katrina Pierson          339906
# 27   MichaelCohen212           Michael Cohen          257489
# 28     foxandfriends           FOX & friends         1012750
# 29      MELANIATRUMP           MELANIA TRUMP          892678
# 30     GeraldoRivera          Geraldo Rivera          157925
# 31       ericbolling            Eric Bolling          729649
# 32     MarkBurnettTV            Mark Burnett          193488
# 33        garyplayer             Gary Player          359255
# 34      VinceMcMahon           Vince McMahon         1789522
# 36      TrumpWaikiki           Trump Waikiki           48325
# 37        TrumpDoral    Trump National Doral           56443
# 38    TrumpCharlotte         Trump Charlotte           38486
# 39     TrumpLasVegas       Trump Vegas Hotel           99719
# 40      TrumpChicago     Trump Hotel Chicago           67529
# 41       TrumpGolfDC    Trump Washington, DC           56428
# ..               ...                     ...             ...
# 61    KellyannePolls        Kellyanne Conway         2584390
# 62            Reince          Reince Priebus          934750
# 63    RealRomaDowney             Roma Downey          238918
# 64             Trump  The Trump Organization          350208
# 67     IngrahamAngle          Laura Ingraham         2581320
# 69         TeamTrump     Official Team Trump          956501
# 72     DRUDGE_REPORT           DRUDGE REPORT         1403331
# 74      LaraLeaTrump              Lara Trump          492595
# 75       seanhannity            Sean Hannity         3928199
# 76     CLewandowski_    Corey R. Lewandowski          388884
# 77    DiamondandSilk       Diamond and Silk®         1010717
# 78    KatrinaCampins         KATRINA CAMPINS          273821
# 79    KatrinaPierson         Katrina Pierson          443386
# 81     foxandfriends           FOX & friends         1335507
# 82      MELANIATRUMP           MELANIA TRUMP         1064983
# 83     GeraldoRivera          Geraldo Rivera          265232
# 84       ericbolling          Eric Bolling🇺🇸         1080806
# 87     MarkBurnettTV            Mark Burnett          219525
# 88        garyplayer             Gary Player          393259
# 89      VinceMcMahon           Vince McMahon         2197623
# 90        DanScavino             Dan Scavino          507539
# 91        TrumpDoral    Trump National Doral           87502
# 92    TrumpCharlotte         Trump Charlotte           69155
# 93     TrumpLasVegas       Trump Vegas Hotel          126917
# 94      TrumpChicago     Trump Hotel Chicago           94208
# 95       TrumpGolfDC    Trump Washington, DC           98794
# 96       TrumpGolfLA       Trump Los Angeles           81502
# 99             greta      Greta Van Susteren         1201546
# 101      piersmorgan            Piers Morgan         6535363
# 103      IvankaTrump            Ivanka Trump         6159430
#
#                            location
# 0                    Washington, DC
# 3                    Washington, DC
# 5                    Washington, DC
# 6    Kenosha, WI and Washington, DC
# 10                           Malibu
# 11                     New York, NY
# 14                   Washington, DC
# 16                              USA
# 17                              USA
# 19                     New York, NY
# 20                     New York, NY
# 22                   Washington, DC
# 23         Los Angeles/New York, NY
# 24                    United States
# 25                     Peace Within
# 26                   Washington, DC
# 27                     New York, NY
# 28                     New York, NY
# 29                     New York, NY
# 30                     New York, NY
# 31                     New York, NY
# 32                      Los Angeles
# 33                     South Africa
# 34                 Greenwich, Conn.
# 36                    Waikiki, Oahu
# 37                   Miami, Florida
# 38                    Charlotte, NC
# 39                       Las Vegas
# 40                      Chicago, IL
# 41                     Sterling, VA
# ..                              ...
# 61                              USA
# 62   Kenosha, WI and Washington, DC
# 63                  California, USA
# 64                     New York, NY
# 67                   Washington, DC
# 69                              USA
# 72                              USA
# 74                     New York, NY
# 75                     New York, NY
# 76                   Washington, DC
# 77                    United States
# 78                     Peace Within
# 79                   Washington, DC
# 81                     New York, NY
# 82                     New York, NY
# 83                     New York, NY
# 84                     New York, NY
# 87                      Los Angeles
# 88                     South Africa
# 89                 Greenwich, Conn.
# 90                   Washington, DC
# 91                   Miami, Florida
# 92                    Charlotte, NC
# 93                       Las Vegas
# 94                      Chicago, IL
# 95                     Sterling, VA
# 96                  Los Angeles, CA
# 99                   Washington, DC
# 101             London, Newick, LA.
# 103                  Washington, DC
#
# [71 rows x 4 columns]

# %%
# Now I want to eliminate the double locations
# From the table above I see that Reince Priebus has two locations but he also appears twice so I assign to 
# one occurence Kenosha, WI and to the other one Washington, DC
#
# in the column 'location' on line 6 assign 'Kenosha, WI'
df4['location'][6] = 'Kenosha, WI'
# in the column 'location' on line 62 assign Washington, DC'
df4['location'][62] = 'Washington, DC'
df4
# Out:
#          screen_name                    name followers_count  \
# 0      TuckerCarlson          Tucker Carlson         1064787
# 3         WhiteHouse         The White House        15327283
# 5     KellyannePolls        Kellyanne Conway         1664393
# 6             Reince          Reince Priebus          941927
# 10    RealRomaDowney             Roma Downey          192126
# 11             Trump      Trump Organization          254702
# 14     IngrahamAngle          Laura Ingraham         1664852
# 16         TeamTrump     Official Team Trump          742514
# 17     DRUDGE_REPORT           DRUDGE REPORT         1319753
# 19      LaraLeaTrump              Lara Trump          301998
# 20       seanhannity            Sean Hannity         2754923
# 22     CLewandowski_    Corey R. Lewandowski          285315
# 23        AnnCoulter             Ann Coulter         1662294
# 24    DiamondandSilk       Diamond and Silk®          382889
# 25    KatrinaCampins         KATRINA CAMPINS          307559
# 26    KatrinaPierson         Katrina Pierson          339906
# 27   MichaelCohen212           Michael Cohen          257489
# 28     foxandfriends           FOX & friends         1012750
# 29      MELANIATRUMP           MELANIA TRUMP          892678
# 30     GeraldoRivera          Geraldo Rivera          157925
# 31       ericbolling            Eric Bolling          729649
# 32     MarkBurnettTV            Mark Burnett          193488
# 33        garyplayer             Gary Player          359255
# 34      VinceMcMahon           Vince McMahon         1789522
# 36      TrumpWaikiki           Trump Waikiki           48325
# 37        TrumpDoral    Trump National Doral           56443
# 38    TrumpCharlotte         Trump Charlotte           38486
# 39     TrumpLasVegas       Trump Vegas Hotel           99719
# 40      TrumpChicago     Trump Hotel Chicago           67529
# 41       TrumpGolfDC    Trump Washington, DC           56428
# ..               ...                     ...             ...
# 61    KellyannePolls        Kellyanne Conway         2584390
# 62            Reince          Reince Priebus          934750
# 63    RealRomaDowney             Roma Downey          238918
# 64             Trump  The Trump Organization          350208
# 67     IngrahamAngle          Laura Ingraham         2581320
# 69         TeamTrump     Official Team Trump          956501
# 72     DRUDGE_REPORT           DRUDGE REPORT         1403331
# 74      LaraLeaTrump              Lara Trump          492595
# 75       seanhannity            Sean Hannity         3928199
# 76     CLewandowski_    Corey R. Lewandowski          388884
# 77    DiamondandSilk       Diamond and Silk®         1010717
# 78    KatrinaCampins         KATRINA CAMPINS          273821
# 79    KatrinaPierson         Katrina Pierson          443386
# 81     foxandfriends           FOX & friends         1335507
# 82      MELANIATRUMP           MELANIA TRUMP         1064983
# 83     GeraldoRivera          Geraldo Rivera          265232
# 84       ericbolling          Eric Bolling🇺🇸         1080806
# 87     MarkBurnettTV            Mark Burnett          219525
# 88        garyplayer             Gary Player          393259
# 89      VinceMcMahon           Vince McMahon         2197623
# 90        DanScavino             Dan Scavino          507539
# 91        TrumpDoral    Trump National Doral           87502
# 92    TrumpCharlotte         Trump Charlotte           69155
# 93     TrumpLasVegas       Trump Vegas Hotel          126917
# 94      TrumpChicago     Trump Hotel Chicago           94208
# 95       TrumpGolfDC    Trump Washington, DC           98794
# 96       TrumpGolfLA       Trump Los Angeles           81502
# 99             greta      Greta Van Susteren         1201546
# 101      piersmorgan            Piers Morgan         6535363
# 103      IvankaTrump            Ivanka Trump         6159430
#
#                      location
# 0              Washington, DC
# 3              Washington, DC
# 5              Washington, DC
# 6                 Kenosha, WI
# 10                     Malibu
# 11               New York, NY
# 14             Washington, DC
# 16                        USA
# 17                        USA
# 19               New York, NY
# 20               New York, NY
# 22             Washington, DC
# 23   Los Angeles/New York, NY
# 24              United States
# 25               Peace Within
# 26             Washington, DC
# 27               New York, NY
# 28               New York, NY
# 29               New York, NY
# 30               New York, NY
# 31               New York, NY
# 32                Los Angeles
# 33               South Africa
# 34           Greenwich, Conn.
# 36              Waikiki, Oahu
# 37             Miami, Florida
# 38              Charlotte, NC
# 39                 Las Vegas
# 40                Chicago, IL
# 41               Sterling, VA
# ..                        ...
# 61                        USA
# 62             Washington, DC
# 63            California, USA
# 64               New York, NY
# 67             Washington, DC
# 69                        USA
# 72                        USA
# 74               New York, NY
# 75               New York, NY
# 76             Washington, DC
# 77              United States
# 78               Peace Within
# 79             Washington, DC
# 81               New York, NY
# 82               New York, NY
# 83               New York, NY
# 84               New York, NY
# 87                Los Angeles
# 88               South Africa
# 89           Greenwich, Conn.
# 90             Washington, DC
# 91             Miami, Florida
# 92              Charlotte, NC
# 93                 Las Vegas
# 94                Chicago, IL
# 95               Sterling, VA
# 96            Los Angeles, CA
# 99             Washington, DC
# 101       London, Newick, LA.
# 103            Washington, DC
#
# [71 rows x 4 columns]

# %%
# Ann Coulter also has a double location so I check whether she also appears twice (she does not)
df4[df4.name == 'Ann Coulter']
# Out:
#    screen_name         name followers_count                  location
# 23  AnnCoulter  Ann Coulter         1662294  Los Angeles/New York, NY

# %%
# I just keep Los Angeles
df4['location'][23] = 'Los Angeles, CA'
df4['location'].unique()
# Out:
# array(['Washington, DC', 'Kenosha, WI', 'Malibu', 'New York, NY', 'USA',
#        'Los Angeles, CA', 'United States', 'Peace Within', 'Los Angeles',
#        'South Africa', 'Greenwich, Conn.', 'Waikiki, Oahu',
#        'Miami, Florida', 'Charlotte, NC', 'Las Vegas ', 'Chicago, IL',
#        'Sterling, VA', 'Manhasset, NY', 'London, Newick, LA. ',
#        '1600 Pennsylvania Avenue ', 'California, USA',
#        'London, Newick, LA.'], dtype=object)

# %%
# look for all entities with location equal 'London, Newick, LA. ' or 'London, Newick, LA.'
df4[(df4.location == 'London, Newick, LA. ') | (df4.location == 'London, Newick, LA.')]
# Out:
#      screen_name          name followers_count              location
# 46   piersmorgan  Piers Morgan         6035181  London, Newick, LA.
# 101  piersmorgan  Piers Morgan         6535363   London, Newick, LA.

# %%
# make one in London and one in LA
df4['location'][46] = 'London, UK'
df4['location'][101] = 'Los Angeles, CA'
df4['location'].unique()
# Out:
# array(['Washington, DC', 'Kenosha, WI', 'Malibu', 'New York, NY', 'USA',
#        'Los Angeles, CA', 'United States', 'Peace Within', 'Los Angeles',
#        'South Africa', 'Greenwich, Conn.', 'Waikiki, Oahu',
#        'Miami, Florida', 'Charlotte, NC', 'Las Vegas ', 'Chicago, IL',
#        'Sterling, VA', 'Manhasset, NY', 'London, UK',
#        '1600 Pennsylvania Avenue ', 'California, USA'], dtype=object)

# %%
# Last few changes
df5=df4.replace(regex={r'United States': 'USA', '^Los Angeles$': 'Los Angeles, CA', '1600 Pennsylvania Avenue ': '1600 Pennsylvania Avenue, Washington, DC'})
df5['location'].unique()
# Out:
# array(['Washington, DC', 'Kenosha, WI', 'Malibu', 'New York, NY', 'USA',
#        'Los Angeles, CA', 'Peace Within', 'South Africa',
#        'Greenwich, Conn.', 'Waikiki, Oahu', 'Miami, Florida',
#        'Charlotte, NC', 'Las Vegas ', 'Chicago, IL', 'Sterling, VA',
#        'Manhasset, NY', 'London, UK',
#        '1600 Pennsylvania Avenue, Washington, DC', 'California, USA'],
#       dtype=object)

# %%
df5.to_csv('cleanDataFromTweeter.txt')

# %% [markdown]
# #### Do the remaining exercises in the CleaningDataExercises notebook
